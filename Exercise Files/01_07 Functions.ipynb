# %%
def greet():
  print("Hello world")

# %%
greet()
# Out:
# Hello world

# %%
def greet(name):
  print("Hello " + name)

# %%
greet("Deepak")
# Out:
# Hello Deepak

# %%
def add_numbers(num1, num2):
  return num1+num2

# %%
sum = add_numbers(10,20)
print(sum)
# Out:
# 30
