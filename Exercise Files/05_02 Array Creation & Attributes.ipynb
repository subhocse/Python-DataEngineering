# %%
import numpy as np

nums = [1,2,3,4,5]

arrayy1 = np.array(nums)
print(arrayy1)
# Out:
# [1 2 3 4 5]

# %%
zero_array = np.zeros(5)
print(zero_array)
# Out:
# [0. 0. 0. 0. 0.]

# %%
one_array = np.ones(3)
print(one_array)
# Out:
# [1. 1. 1.]

# %%
range_array = np.arange(1,10,2)
print(range_array)
# Out:
# [1 3 5 7 9]

# %%
random_array = np.random.randint(1,100,5)
print(random_array)
# Out:
# [45 46 32  6  8]

# %%
random_matrix = np.random.rand(3,3)
print(random_matrix)
# Out:
# [[0.8238973  0.33156943 0.33737945]
#  [0.04392795 0.63867738 0.87409243]
#  [0.47270233 0.26310235 0.35714722]]

# %%
shape = range_array.shape
print(shape)
# Out:
# (5,)

# %%
size = range_array.size
print(size)
# Out:
# 5

# %%
dtype = range_array.dtype
print(dtype)
# Out:
# int64

# %%
print(range_array.ndim)
# Out:
# 1
