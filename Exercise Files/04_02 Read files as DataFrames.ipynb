# %%
import pandas as pd

df = pd.read_csv('/content/Order.csv')

print(df)
# Out:
#                            Region               Country    ItemType  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     SalesChannel OrderPriority    OrderID  UnitsSold  UnitPrice  UnitCost  \
# 0        Offline             M  686800706       8446     437.20    263.33
# ...

# %%
print(df.to_string())
# Out:
#                                 Region                           Country         ItemType SalesChannel OrderPriority    OrderID  UnitsSold  UnitPrice  UnitCost  TotalRevenue   TotalCost  TotalProfit  order_date
# 0         Middle East and North Africa                             Libya        Cosmetics      Offline             M  686800706       8446     437.20    263.33    3692591.20  2224085.18   1468506.02  13022023.0
# 1                        North America                            Canada       Vegetables       Online             M  185941302       3018     154.06     90.93     464953.08   274426.74    190526.34  28032023.0
# 2         Middle East and North Africa                             Libya        Baby Food      Offline             C  246222341       1517     255.28    159.42     387259.76   241840.14    145419.62   8092022.0
# ...

# %%
import pandas as pd

df = pd.read_json('/content/sample_data/anscombe.json')
print(df)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
df = pd.read_excel('/content/Customer_excel.xlsx')
print(df.to_string())
# Out:
#      customer_id    first_name           last_name                                  email         phone         country                  city   registration_date       date_of_birth  gender
# 0         1001.0         Bruis               Myall                       bmyall0@hibu.com  3.604158e+09   United States             Vancouver 2022-09-23 11:10:45 2023-02-13 03:14:05    Male
# 1         1002.0        Ellene          MacSporran              emacsporran1@mapquest.com  9.011721e+09   United States               Memphis 2022-10-15 18:01:12 2023-03-28 13:09:21  Female
# 2         1003.0     Isabelita          Powlesland        ipowlesland2@chicagotribune.com  7.081891e+09  United Kingdom             Liverpool 2022-06-20 03:55:09 2022-09-08 06:25:57  Female
# 3         1004.0         Elden                Tonn                     etonn3@t-online.de  8.156364e+09   United States              Rockford 2023-03-08 09:56:41 2023-01-07 01:31:46    Male
# ...
