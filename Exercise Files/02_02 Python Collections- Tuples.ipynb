# %%
employee = (1, 'Deepak', 'Indore', 98323333)
print(employee)
# Out:
# (1, 'Deepak', 'Indore', 98323333)

# %%
print(employee[1])
# Out:
# Deepak

# %%
print(len(employee))
# Out:
# 4

# %%
print(employee[-1])
# Out:
# 98323333

# %%
employee = (1, 'Deepak', 'Indore', 98323333)
new_emp = list(employee)
new_emp[1] = 'Deepak Goyal'
employee =tuple(new_emp)
print(employee)
# Out:
# (1, 'Deepak Goyal', 'Indore', 98323333)

# %%
for x in employee:
  print(x)
# Out:
# 1
# Deepak Goyal
# Indore
# 98323333

# %%
print(employee.index('Indore'))
# Out:
# 2
