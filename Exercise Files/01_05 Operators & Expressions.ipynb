# %%
greeting = "Hello Data engineering"
print(greeting)
# Out:
# Hello Data engineering

# %%
int_var = 7
float_var = 3.14
str_var = "Hello world"
bol_var = True

# %%
print(int_var)
# Out:
# 7

# %%
num1 = 7
num2 = 10

sum  = num1 + num2

print(sum)
# Out:
# 17

# %%
sub = num1 - num2
mul = num1*num2
divison = num2/num1

print(sub)
print(mul)
print(divison)
# Out:
# -3
# 70
# 1.4285714285714286

# %%
var_equal = num1==num2
print(var_equal)
# Out:
# False

# %%
not_equal = num1 != num2
print(not_equal)
# Out:
# True

# %%
gret = num1>num2
print(gret)
# Out:
# False

# %%
print( True and False)
# Out:
# False

# %%
print( True or False)
# Out:
# True

# %%
num = 7

if num > 10:
  print("Greater")
else:
  print("Smaller")
# Out:
# Smaller

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number  =5
while number >=0:
  print(number)
  number = number-1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
